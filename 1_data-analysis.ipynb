# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from util import get_preprocessed_train_data

# %%
df = get_preprocessed_train_data()

# %%
df.shape
# Out:
# (355, 35)

# %%
df.describe()
# Out:
#        Unnamed: 0         age        Medu        Fedu  traveltime   studytime  \
# count  355.000000  355.000000  355.000000  355.000000  355.000000  355.000000
# mean   177.000000   16.698592    2.740845    2.540845    1.430986    2.028169
# std    102.623909    1.274200    1.092033    1.079022    0.695139    0.829741
# min      0.000000   15.000000    0.000000    0.000000    1.000000    1.000000
# 25%     88.500000   16.000000    2.000000    2.000000    1.000000    1.000000
# 50%    177.000000   17.000000    3.000000    3.000000    1.000000    2.000000
# 75%    265.500000   18.000000    4.000000    3.000000    2.000000    2.000000
# max    354.000000   22.000000    4.000000    4.000000    4.000000    4.000000
#
#          failures      famrel    freetime       goout        Dalc        Walc  \
# count  355.000000  333.000000  355.000000  355.000000  355.000000  355.000000
# mean     0.338028    3.939940    3.219718    3.138028    1.484507    2.332394
# std      0.746814    0.903138    1.009646    1.127765    0.880846    1.294030
# min      0.000000    1.000000    1.000000    1.000000    1.000000    1.000000
# 25%      0.000000    4.000000    3.000000    2.000000    1.000000    1.000000
# 50%      0.000000    4.000000    3.000000    3.000000    1.000000    2.000000
# 75%      0.000000    5.000000    4.000000    4.000000    2.000000    3.000000
# max      3.000000    5.000000    5.000000    5.000000    5.000000    5.000000
#
#            health    absences          G1          G2          G3       G_avg
# count  355.000000  355.000000  355.000000  355.000000  355.000000  355.000000
# mean     3.557746    5.667606    1.622418    1.612324    1.600587    1.611776
# std      1.403754    8.126955    0.135986    0.155574    0.188980    0.152249
# min      1.000000   -1.000000    1.375000    1.166667    1.166667    1.236111
# 25%      3.000000    0.000000    1.500000    1.541667    1.541667    1.513889
# 50%      4.000000    4.000000    1.625000    1.625000    1.625000    1.611111
# 75%      5.000000    8.000000    1.708333    1.708333    1.708333    1.722222
# max      5.000000   75.000000    1.958333    1.958333    2.000000    1.972222

# %%
fig, ax = plt.subplots(figsize=(20,15))
plt.title('G1')
_ = sns.distplot(df['G1'], ax=ax, kde=False)
# Out:
# /Users/benjaminmeyer/PycharmProjects/mllab-student-grade-prediction/venv/lib/python3.7/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
fig, ax = plt.subplots(figsize=(20,15))
plt.title('G2')
_ = sns.distplot(df['G2'], ax=ax, kde=False)

# %%
fig, ax = plt.subplots(figsize=(20,15))
plt.title('G3')
_ = sns.distplot(df['G3'], ax=ax, kde=False)

# %%
fig, ax = plt.subplots(figsize=(20,15))
plt.title('G_avg')
_ = sns.distplot(df['G_avg'], ax=ax, kde=False)

# %%
corr = df.corr()

# Generate a mask for the upper triangle
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

# Set up the matplotlib figure
fig, ax = plt.subplots(figsize=(20, 15))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
_ = sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %% [markdown]
# Divide features into General and Specific Type:
#
# | Feature       | General Type  | Specific Type|
# | ------------- |:-------------:| -----------:|
# | school        | Categorical   | Nominal     |
# | sex           | Categorical   | Nominal     |
# | age           | Numeric       | Discrete    |
# | address       | Categorical   | Nominal     |
# | famsize       | Categorical   | Oridinal    |
# | Pstatus       | Categorical   | Nominal     |
# | Medu          | Categorical   | Oridinal    |
# | Fedu          | Categorical   | Oridinal    |
# | Mjob          | Categorical   | Nominal     |
# | Fjob          | Categorical   | Nominal     |
# | reason        | Categorical   | Nominal     |
# | guardian      | Categorical   | Nominal     |
# | traveltime    | Numeric       | Continuous  |
# | studytime     | Categorical   | Oridinal    |
# | failures      | Categorical   | Oridinal    |
# | schoolsup     | Categorical   | Nominal     |
# | famsup        | Categorical   | Nominal     |
# | paid          | Categorical   | Nominal     |
# | activities    | Categorical   | Nominal     |
# | nursery       | Categorical   | Nominal     |
# | higher        | Categorical   | Nominal     |
# | internet      | Categorical   | Nominal     |
# | romantic      | Categorical   | Nominal     |
# | famrel        | Categorical   | Oridinal    |
# | freetime      | Categorical   | Oridinal    |
# | goout         | Categorical   | Oridinal    |
# | Dalc          | Categorical   | Oridinal    |
# | Walc          | Categorical   | Oridinal    |
# | health        | Categorical   | Oridinal    |
# | absences      | Numeric       | Discrete    |
